# %%
# 17-April-2024
# CSC354 – Assignmen3 – ML – Support Vector Machines
# Abdul Rehman Butt
# FA21-BSE-098
# Fitting a linear SVM using custom values of C regularization parameter on the dataset and plotting the decision boundary and training data points using a scatter plot

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

path = "/content/drive/MyDrive/Machine Learning/Assignment 3/"

data = pd.read_csv(path + "dataset-q-1.csv")

X = data.drop(data.columns[2], axis=1)
y = data.iloc[:, 2]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

svm_model = SVC(kernel='linear', C=0.01)
svm_model.fit(X_scaled, y)
# Out:
# SVC(C=0.01, kernel='linear')

# %%
def plot_with_boundary(X, y, model):
    positive_points = X[y == 1]
    negative_points = X[y == -1]

    plt.scatter(positive_points[:, 0], positive_points[:, 1], c='green', label='Positive')
    plt.scatter(negative_points[:, 0], negative_points[:, 1], c='purple', label='Negative')

    coef = model.coef_[0]
    intercept = model.intercept_

    # Plotting the decision boundary line
    x_values = np.array([X[:, 0].min(), X[:, 0].max()])
    y_values = (-coef[0] / coef[1]) * x_values - (intercept / coef[1])
    plt.plot(x_values, y_values, linestyle='--', color='blue', label='Decision Boundary')

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Data Points with Decision Boundary')
    plt.legend()
    plt.show()

plot_with_boundary(X_scaled, y, svm_model)

# %% [markdown]
# 1. Plot again and note down your findings. Does the hyperplane misclassify (handle) any outliers?
# With C = 0.01 the boundary line is classifing all the instances to one class means misclassifying the half instances and with this model it will misclassify the future points as well.
# 2. Try increasing the value of C (100, 300, 700, 1000) and observe the effect on the resulting hyperplanes.
# Write down your findings.
# By increasing the value of C at 100, 300, 700, 1000 the model is working very good and the boundary line is same with all of these values as it can be seen from the above plot but it is different from default boundary line as it was classifying one instance to the opposite side of the boundary line means in that model the distance was maximum and it allowed one outlier.
